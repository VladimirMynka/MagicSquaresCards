# %%
import pandas as pd

df = pd.read_csv('cards/cards_metadata.csv')

df
# Out:
#                                     filename  \
# 0                     Главное1Определение.md
# 1                          Главное2Пример.md
# 2                     Главное3Определение.md
# 3                          Алгебра1Модель.md
# 4                         Алгебра2Теорема.md
# ..                                       ...
# 178        Квадраты4Из9ОпределениеЗеленые.md
# 179     Квадраты4Из9ОпределениеТемноСерые.md
# 180    Квадраты4Из9ОпределениеСветлоСерые.md
# 181  Квадраты5Из9ОпределениеКрасноКрасные.md
# 182   Квадраты5Из9ОпределениеКрасноЖелтые.md
#
#                                              title    info_type  \
# 0                 Определение магического квадрата       1_Main
# 1                      Пример магического квадрата       1_Main
# 2     Определение квадратного магического квадрата       1_Main
# 3                  АВС-модель магического квадрата       1_Main
# 4                   Теорема о магической константе       1_Main
# ...
